# %%
import pandas as pd
import numpy as np
data = pd.read_csv('delighted-data_25-July-2019.csv')
data = data.drop(columns=['Response ID','Notes','Tags', 'Delighted Email Subject', 'Delighted Intro Message',
                         'first%20name', 'graduation%20date', 'last%20name', 
                         'Name.1', 'purchase_location','Survey%20Type','survey%20type',
                         'Survey Type','type%20of%20course','Response Timestamp'])
data = data.drop(columns=['first name', 'last name', 'Delighted Source', 'Email.1', 'Graduation date', 'Graduation data', 'Type of course'])

# %%
data.shape
# Out:
# (1572, 6)

# %%
data.head(2)
# Out:
#           Name                  Email  Score  \
# 0  Robin Hahne  hahne.robin@gmail.com      9
# 1  Flora Thiam  florathiam@hotmail.fr      9
#
#                                              Comment       city  \
# 0  I assume that the question above should be "Te...  Amsterdam
# 1  Loved the experience: teaching team, atmospher...  Amsterdam
#
#                           cohort
# 0  Amsterdam Jan FTWD 2019-01-28
# 1  Amsterdam Jan FTUX 2019-01-14

# %%
for i in data['cohort'].str.contains('FT|Full|FULL'):
    if True:
        data['COHORT'] = 'FullTime'

# %%
data.head(10)
# Out:
#                                 Name                      Email  Score  \
# 0                        Robin Hahne      hahne.robin@gmail.com      9
# 1                        Flora Thiam      florathiam@hotmail.fr      9
# 2                    Neville Tjon-Fo      nefdesign@hotmail.com      9
# 3                         JoepSeuren         mail@joepseuren.nl      8
# 4                      JelteHomminga    jeltehomminga@gmail.com      9
# 5            Eugene Bos Wiafe-Dadzie         mrdadzie@gmail.com      7
# 6                    Julia Caraballo  julia.caraballo@gmail.com      5
# 7  João Pedro Serrat de Souza Santos      jp_serrat@hotmail.com     10
# 8        Javier Pérez-Chao Rodríguez      javiermaker@gmail.com      8
# 9                      Isabela Oñate    isabellaonate@gmail.com     10
#
#                                              Comment       city  \
# 0  I assume that the question above should be "Te...  Amsterdam
# ...
